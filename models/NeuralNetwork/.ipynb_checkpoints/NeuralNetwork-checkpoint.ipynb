# %%
import os 
import random
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from IPython.display import display
from sklearn.preprocessing import MinMaxScaler

from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import sys
sys.path.append('../..')
from data.data_loader import get_splits
from utils.plot import plot_2D


#data = pd.read_csv("../../data/vehicles_cleaner.csv", names = ["City","Price","Year","Make","Model","Condition","Cylinders","Gas type","Odometer","Title status","Transmission type","Drive type","Size","Car type","Color","State"])
#data=data.drop('City',1)
data = get_splits('../../data/vehicles_cleaner.csv', 0.2)
#display(data)

"""new_data = data[data['Model'] != 'NOTVALID']
display(new_data['Model'])
price_data=new_data['Price']
features_data=new_data.drop('Price',1)"""



"""x = features_data.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
features_data = pd.DataFrame(x_scaled)
display(features_data)"""
X_train = data['X_train']
y_train = data['Y_train']
X_test = data['X_test']
y_test = data['Y_test']

display(X_train)
display(y_train)
display(X_test)
display(y_test)

scaler = MinMaxScaler() 
# It resizes to 0-1 for easier processing of data.
numerical = ['year', 'make', 'model','condition','cylinders','fuel','odometer', 'title_status','transmission','drive','size','type','paint_color','state']
X_train[numerical] = scaler.fit_transform(X_train[numerical])   
# Creating dummy variables for categorical data.
#features_data = pd.get_dummies(features_data)  
encoded = list(X_train.columns) 
display("There are {} features after one hot encoding".format(len(encoded))) 
display(encoded)

# It resizes to 0-1 for easier processing of data.
numerical = ['year', 'make', 'model','condition','cylinders','fuel','odometer', 'title_status','transmission','drive','size','type','paint_color','state']
X_test[numerical] = scaler.fit_transform(X_test[numerical])   
# Creating dummy variables for categorical data.
#features_data = pd.get_dummies(features_data)  
encoded = list(X_test.columns) 
display("There are {} features after one hot encoding".format(len(encoded))) 
display(encoded)

X_train,X_val,y_train,y_val = train_test_split(X_train, y_train, test_size = 0.25, random_state = 0)

# Show the results of the split
print("The train set has an example of {}.".format(X_train.shape[0]))
print("Validation set has an example of {}.".format(X_val.shape[0]))
print("The test set has an example of {}.".format(X_test.shape[0]))

X_train=np.array(X_train) #lists are converted to numpy arrays
y_train=np.array(y_train)
X_val=np.array(X_val)
y_val=np.array(y_val)
X_test=np.array(X_test)
y_test=np.array(y_test)
# Out:
#        year  make model  condition  cylinders  fuel  odometer  title_status  \
# 9024      7     4     2         -1          1     0  107131.0             0
# 10516    11     4     2         -1         -1     0   56905.0             0
# 5223      5     4     8         -1         -1     0   59569.0             0
# 11204    19     4     2          3         -1     2  120700.0             1
# 5414      8     4     2         -1          3     0   62974.0             0
# ...     ...   ...   ...        ...        ...   ...       ...           ...
# 1287     10     4     4          3          3     0  154000.0             0
# 2860     14     4    18         -1         -1     0  109125.0             0
# 12327     8     4    12          2          3     1   72512.0             0
# 9280     12     4     5          1          4     0  102447.0             0
# 10560     4     4     2         -1         -1     0   17049.0             0
#
#        transmission  drive  size  type  paint_color  state
# 9024              1      0    -1     3            5     30
# 10516             1     -1    -1    -1            4     36
# 5223              1     -1     2     2            0      9
# 11204             1      1     0     8           10     38
# 5414              1      2    -1     8            6      9
# ...             ...    ...   ...   ...          ...    ...
# 1287              1      2     1     3            2      0
# 2860              1     -1     3     7           -1      4
# 12327             1      0    -1     2            0     43
# 9280              1      2    -1     8            1     30
# 10560             1      2    -1    -1            4     36
#
# [8613 rows x 14 columns]
# 9024     10495
# 10516    13998
# 5223     14940
# 11204     2750
# 5414     16991
#          ...
# 1287      6000
# 2860     19999
# 12327    17995
# 9280      7995
# 10560    21220
# Name: price, Length: 8613, dtype: int64
#       year  make model  condition  cylinders  fuel  odometer  title_status  \
# 4308    33     4     2         -1          3     0  217319.0             0
# 1690     5     4    26         -1          3     0   95309.0             0
# 5034     8     4     4          2          3     0   94053.0             0
# 3570    12     4     2          3          3     0   95000.0             0
# 2723     5     4     8          2          1     0   78000.0             0
# ...    ...   ...   ...        ...        ...   ...       ...           ...
# 5640     6     4    20          2          4     0   56899.0             0
# 7283    11     4     2          2          0     0  114000.0             0
# 6789    14     4     4          2          3     0  154000.0             0
# 6283     5     4    12         -1          4     0   12662.0             0
# 970      6     4     8         -1         -1     0   69100.0             0
#
#       transmission  drive  size  type  paint_color  state
# 4308             0      2    -1    -1            6      6
# 1690             1      2    -1     2            0      4
# 5034             1      2     0     3            1      9
# 3570             1      2    -1     3            1      4
# 2723             1     -1    -1     2           -1      4
# ...            ...    ...   ...   ...          ...    ...
# 5640             0      2     0     3            0      9
# 7283             1     -1     1     3           -1     20
# 6789             1      0     1     3           -1     15
# 6283             1      0    -1     2           -1     11
# 970              1     -1    -1    -1           -1     49
#
# [2154 rows x 14 columns]
# 4308     7750
# 1690    21991
# 5034    12950
# 3570     5800
# 2723    12999
#         ...
# 5640        1
# 7283     5985
# 6789     4600
# 6283    34995
# 970     13950
# Name: price, Length: 2154, dtype: int64
# 'There are 14 features after one hot encoding'
# ['year',
#  'make',
#  'model',
#  'condition',
#  'cylinders',
#  'fuel',
#  'odometer',
#  'title_status',
#  'transmission',
#  'drive',
#  'size',
#  'type',
#  'paint_color',
#  'state']
# 'There are 14 features after one hot encoding'
# ['year',
#  'make',
#  'model',
#  'condition',
#  'cylinders',
#  'fuel',
#  'odometer',
#  'title_status',
#  'transmission',
#  'drive',
#  'size',
#  'type',
#  'paint_color',
#  'state']
# The train set has an example of 6459.
# Validation set has an example of 2154.
# The test set has an example of 2154.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.callbacks import ModelCheckpoint, Callback
from keras import backend
#from tensorflow.keras import backend

# Lost function is selected as mean absolute error
loss_function='mean_absolute_error'
# The sequential model is created to use compile-fit-evaluate-predict methods
price_predictor = Sequential()
# Neural network layers are created with RELU activation
price_predictor.add(Dense(128,activation='relu', input_dim=14))  
price_predictor.add(Dense(64))
price_predictor.add(Dense(32,activation='relu'))
price_predictor.add(Dense(8))
price_predictor.add(Dense(1))
price_predictor.summary()

test_errs = []
# Here the Adam optimizer (different type of stochastic gradient descent) is used.
price_predictor.compile(optimizer='Adam', loss=loss_function)

# It allows new callbacks by abstracting the base class.
checkpointer = ModelCheckpoint(filepath='price_prediction.hdf5', verbose=1, save_best_only=True)

# Trains the model according to the number of epoch given.
#price_predictor.fit(X_train, y_train, validation_data=[X_val,y_val], epochs=20, batch_size=500, callbacks=[checkpointer], verbose=0) 
i=0;
epoch = [10,30,50,70,90,110,130,150]
while(i<8):
    price_predictor.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epoch[i], batch_size=500, callbacks=[checkpointer], verbose=0)
    price_predictor.load_weights('price_prediction.hdf5')
    score=price_predictor.evaluate(X_test,y_test,verbose=1)
    display("The final model scores {} for test data.".format(score))
    test_errs.append(score)
    i=i+1
    
price_prediction=price_predictor.predict(X_test)

"""model = Sequential([
    Dense(85, activation='relu', input_shape=(1079,)),
    Dense(85, activation='relu'),
    Dense(1, activation='sigmoid'),
])

model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])


model.fit(X_train, y_train,
          batch_size=32, epochs=10,
          validation_data=(X_val, y_val))"""
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 128)               1920
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_19 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 12,529
# Trainable params: 12,529
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 00001: val_loss improved from inf to 14817.88427, saving model to price_prediction.hdf5
#
# Epoch 00002: val_loss improved from 14817.88427 to 14812.45916, saving model to price_prediction.hdf5
#
# Epoch 00003: val_loss improved from 14812.45916 to 14794.85165, saving model to price_prediction.hdf5
#
# Epoch 00004: val_loss improved from 14794.85165 to 14743.03388, saving model to price_prediction.hdf5
#
# Epoch 00005: val_loss improved from 14743.03388 to 14608.54077, saving model to price_prediction.hdf5
#
# Epoch 00006: val_loss improved from 14608.54077 to 14300.96431, saving model to price_prediction.hdf5
#
# Epoch 00007: val_loss improved from 14300.96431 to 13674.54072, saving model to price_prediction.hdf5
#
# Epoch 00008: val_loss improved from 13674.54072 to 12546.19185, saving model to price_prediction.hdf5
#
# Epoch 00009: val_loss improved from 12546.19185 to 10907.60435, saving model to price_prediction.hdf5
#
# Epoch 00010: val_loss improved from 10907.60435 to 9337.99649, saving model to price_prediction.hdf5
# 2154/2154 [==============================] - 0s 33us/step
# 'The final model scores 9122.310233141829 for test data.'
# Epoch 00001: val_loss improved from 9337.99649 to 8587.20397, saving model to price_prediction.hdf5
#
# Epoch 00002: val_loss improved from 8587.20397 to 8434.76374, saving model to price_prediction.hdf5
#
# Epoch 00003: val_loss improved from 8434.76374 to 8348.18948, saving model to price_prediction.hdf5
#
# Epoch 00004: val_loss improved from 8348.18948 to 8281.60873, saving model to price_prediction.hdf5
#
# Epoch 00005: val_loss improved from 8281.60873 to 8195.85760, saving model to price_prediction.hdf5
#
# Epoch 00006: val_loss improved from 8195.85760 to 8104.98417, saving model to price_prediction.hdf5
#
# Epoch 00007: val_loss improved from 8104.98417 to 8022.97656, saving model to price_prediction.hdf5
#
# Epoch 00008: val_loss improved from 8022.97656 to 7943.48675, saving model to price_prediction.hdf5
#
# Epoch 00009: val_loss improved from 7943.48675 to 7860.61764, saving model to price_prediction.hdf5
#
# Epoch 00010: val_loss improved from 7860.61764 to 7778.35251, saving model to price_prediction.hdf5
#
# Epoch 00011: val_loss improved from 7778.35251 to 7695.10010, saving model to price_prediction.hdf5
#
# Epoch 00012: val_loss improved from 7695.10010 to 7609.15191, saving model to price_prediction.hdf5
#
# Epoch 00013: val_loss improved from 7609.15191 to 7537.10151, saving model to price_prediction.hdf5
#
# Epoch 00014: val_loss improved from 7537.10151 to 7442.51884, saving model to price_prediction.hdf5
#
# Epoch 00015: val_loss improved from 7442.51884 to 7349.62042, saving model to price_prediction.hdf5
#
# Epoch 00016: val_loss improved from 7349.62042 to 7267.19725, saving model to price_prediction.hdf5
#
# Epoch 00017: val_loss improved from 7267.19725 to 7168.27869, saving model to price_prediction.hdf5
#
# Epoch 00018: val_loss improved from 7168.27869 to 7069.37416, saving model to price_prediction.hdf5
#
# Epoch 00019: val_loss improved from 7069.37416 to 6970.53790, saving model to price_prediction.hdf5
#
# Epoch 00020: val_loss improved from 6970.53790 to 6868.48964, saving model to price_prediction.hdf5
#
# Epoch 00021: val_loss improved from 6868.48964 to 6777.55747, saving model to price_prediction.hdf5
#
# Epoch 00022: val_loss improved from 6777.55747 to 6688.02231, saving model to price_prediction.hdf5
#
# Epoch 00023: val_loss improved from 6688.02231 to 6592.87037, saving model to price_prediction.hdf5
#
# Epoch 00024: val_loss improved from 6592.87037 to 6519.78446, saving model to price_prediction.hdf5
#
# Epoch 00025: val_loss improved from 6519.78446 to 6430.67087, saving model to price_prediction.hdf5
#
# Epoch 00026: val_loss improved from 6430.67087 to 6356.32620, saving model to price_prediction.hdf5
#
# Epoch 00027: val_loss improved from 6356.32620 to 6286.31286, saving model to price_prediction.hdf5
#
# Epoch 00028: val_loss improved from 6286.31286 to 6220.97672, saving model to price_prediction.hdf5
#
# Epoch 00029: val_loss improved from 6220.97672 to 6153.46875, saving model to price_prediction.hdf5
#
# Epoch 00030: val_loss improved from 6153.46875 to 6099.30701, saving model to price_prediction.hdf5
# 2154/2154 [==============================] - 0s 35us/step
# 'The final model scores 6276.665702345201 for test data.'
# Epoch 00001: val_loss improved from 6099.30701 to 6037.52116, saving model to price_prediction.hdf5
#
# Epoch 00002: val_loss improved from 6037.52116 to 5981.55999, saving model to price_prediction.hdf5
#
# Epoch 00003: val_loss improved from 5981.55999 to 5926.86237, saving model to price_prediction.hdf5
#
# Epoch 00004: val_loss improved from 5926.86237 to 5870.32494, saving model to price_prediction.hdf5
#
# Epoch 00005: val_loss improved from 5870.32494 to 5811.54129, saving model to price_prediction.hdf5
#
# Epoch 00006: val_loss improved from 5811.54129 to 5752.45784, saving model to price_prediction.hdf5
#
# Epoch 00007: val_loss improved from 5752.45784 to 5689.48335, saving model to price_prediction.hdf5
#
# Epoch 00008: val_loss improved from 5689.48335 to 5616.61403, saving model to price_prediction.hdf5
#
# Epoch 00009: val_loss improved from 5616.61403 to 5546.80302, saving model to price_prediction.hdf5
#
# Epoch 00010: val_loss improved from 5546.80302 to 5467.87076, saving model to price_prediction.hdf5
#
# Epoch 00011: val_loss improved from 5467.87076 to 5392.71734, saving model to price_prediction.hdf5
#
# Epoch 00012: val_loss improved from 5392.71734 to 5299.82962, saving model to price_prediction.hdf5
#
# Epoch 00013: val_loss improved from 5299.82962 to 5206.87011, saving model to price_prediction.hdf5
#
# Epoch 00014: val_loss improved from 5206.87011 to 5107.28125, saving model to price_prediction.hdf5
#
# Epoch 00015: val_loss improved from 5107.28125 to 4996.68194, saving model to price_prediction.hdf5
#
# Epoch 00016: val_loss improved from 4996.68194 to 4883.64641, saving model to price_prediction.hdf5
#
# Epoch 00017: val_loss improved from 4883.64641 to 4756.92914, saving model to price_prediction.hdf5
#
# Epoch 00018: val_loss improved from 4756.92914 to 4629.73188, saving model to price_prediction.hdf5
#
# Epoch 00019: val_loss improved from 4629.73188 to 4507.74511, saving model to price_prediction.hdf5
#
# Epoch 00020: val_loss improved from 4507.74511 to 4377.89481, saving model to price_prediction.hdf5
#
# Epoch 00021: val_loss improved from 4377.89481 to 4261.49349, saving model to price_prediction.hdf5
#
# Epoch 00022: val_loss improved from 4261.49349 to 4157.80608, saving model to price_prediction.hdf5
#
# Epoch 00023: val_loss improved from 4157.80608 to 4076.47273, saving model to price_prediction.hdf5
#
# Epoch 00024: val_loss improved from 4076.47273 to 3983.48626, saving model to price_prediction.hdf5
#
# Epoch 00025: val_loss improved from 3983.48626 to 3917.17890, saving model to price_prediction.hdf5
#
# Epoch 00026: val_loss improved from 3917.17890 to 3857.94753, saving model to price_prediction.hdf5
#
# Epoch 00027: val_loss improved from 3857.94753 to 3820.95237, saving model to price_prediction.hdf5
#
# Epoch 00028: val_loss improved from 3820.95237 to 3778.35966, saving model to price_prediction.hdf5
#
# Epoch 00029: val_loss improved from 3778.35966 to 3732.24134, saving model to price_prediction.hdf5
#
# Epoch 00030: val_loss improved from 3732.24134 to 3704.60841, saving model to price_prediction.hdf5
#
# Epoch 00031: val_loss improved from 3704.60841 to 3689.52593, saving model to price_prediction.hdf5
#
# Epoch 00032: val_loss improved from 3689.52593 to 3654.45406, saving model to price_prediction.hdf5
#
# Epoch 00033: val_loss improved from 3654.45406 to 3640.30363, saving model to price_prediction.hdf5
#
# Epoch 00034: val_loss improved from 3640.30363 to 3612.88172, saving model to price_prediction.hdf5
#
# Epoch 00035: val_loss improved from 3612.88172 to 3596.75064, saving model to price_prediction.hdf5
#
# Epoch 00036: val_loss improved from 3596.75064 to 3587.51456, saving model to price_prediction.hdf5
#
# Epoch 00037: val_loss did not improve
#
# Epoch 00038: val_loss improved from 3587.51456 to 3552.90634, saving model to price_prediction.hdf5
#
# Epoch 00039: val_loss improved from 3552.90634 to 3551.78258, saving model to price_prediction.hdf5
#
# Epoch 00040: val_loss did not improve
#
# Epoch 00041: val_loss improved from 3551.78258 to 3519.34254, saving model to price_prediction.hdf5
#
# Epoch 00042: val_loss improved from 3519.34254 to 3498.39578, saving model to price_prediction.hdf5
#
# Epoch 00043: val_loss did not improve
#
# Epoch 00044: val_loss improved from 3498.39578 to 3487.97392, saving model to price_prediction.hdf5
#
# Epoch 00045: val_loss improved from 3487.97392 to 3467.49749, saving model to price_prediction.hdf5
#
# Epoch 00046: val_loss improved from 3467.49749 to 3458.05267, saving model to price_prediction.hdf5
#
# Epoch 00047: val_loss improved from 3458.05267 to 3451.72122, saving model to price_prediction.hdf5
#
# Epoch 00048: val_loss improved from 3451.72122 to 3445.38298, saving model to price_prediction.hdf5
#
# Epoch 00049: val_loss improved from 3445.38298 to 3434.69608, saving model to price_prediction.hdf5
#
# Epoch 00050: val_loss did not improve
# 2154/2154 [==============================] - 0s 31us/step
# 'The final model scores 3749.019804179724 for test data.'
# Epoch 00001: val_loss improved from 3434.69608 to 3428.11277, saving model to price_prediction.hdf5
#
# Epoch 00002: val_loss improved from 3428.11277 to 3419.97220, saving model to price_prediction.hdf5
#
# Epoch 00003: val_loss improved from 3419.97220 to 3412.08708, saving model to price_prediction.hdf5
#
# Epoch 00004: val_loss improved from 3412.08708 to 3406.06220, saving model to price_prediction.hdf5
#
# Epoch 00005: val_loss did not improve
#
# Epoch 00006: val_loss did not improve
#
# Epoch 00007: val_loss improved from 3406.06220 to 3386.51325, saving model to price_prediction.hdf5
#
# Epoch 00008: val_loss did not improve
#
# Epoch 00009: val_loss improved from 3386.51325 to 3375.86920, saving model to price_prediction.hdf5
#
# Epoch 00010: val_loss did not improve
#
# Epoch 00011: val_loss improved from 3375.86920 to 3370.22688, saving model to price_prediction.hdf5
#
# Epoch 00012: val_loss improved from 3370.22688 to 3359.56144, saving model to price_prediction.hdf5
#
# Epoch 00013: val_loss improved from 3359.56144 to 3354.78559, saving model to price_prediction.hdf5
#
# Epoch 00014: val_loss improved from 3354.78559 to 3353.96060, saving model to price_prediction.hdf5
#
# Epoch 00015: val_loss improved from 3353.96060 to 3348.86433, saving model to price_prediction.hdf5
#
# Epoch 00016: val_loss improved from 3348.86433 to 3343.47041, saving model to price_prediction.hdf5
#
# Epoch 00017: val_loss improved from 3343.47041 to 3337.18461, saving model to price_prediction.hdf5
#
# Epoch 00018: val_loss did not improve
#
# Epoch 00019: val_loss improved from 3337.18461 to 3331.28670, saving model to price_prediction.hdf5
#
# Epoch 00020: val_loss improved from 3331.28670 to 3326.26027, saving model to price_prediction.hdf5
#
# Epoch 00021: val_loss did not improve
#
# Epoch 00022: val_loss improved from 3326.26027 to 3322.06226, saving model to price_prediction.hdf5
#
# Epoch 00023: val_loss improved from 3322.06226 to 3316.54917, saving model to price_prediction.hdf5
#
# Epoch 00024: val_loss improved from 3316.54917 to 3314.36001, saving model to price_prediction.hdf5
#
# Epoch 00025: val_loss improved from 3314.36001 to 3309.81875, saving model to price_prediction.hdf5
#
# Epoch 00026: val_loss did not improve
#
# Epoch 00027: val_loss improved from 3309.81875 to 3307.47458, saving model to price_prediction.hdf5
#
# Epoch 00028: val_loss improved from 3307.47458 to 3301.74855, saving model to price_prediction.hdf5
#
# Epoch 00029: val_loss improved from 3301.74855 to 3301.69019, saving model to price_prediction.hdf5
#
# Epoch 00030: val_loss improved from 3301.69019 to 3300.32683, saving model to price_prediction.hdf5
#
# Epoch 00031: val_loss improved from 3300.32683 to 3298.98636, saving model to price_prediction.hdf5
#
# Epoch 00032: val_loss did not improve
#
# Epoch 00033: val_loss improved from 3298.98636 to 3290.89984, saving model to price_prediction.hdf5
#
# Epoch 00034: val_loss improved from 3290.89984 to 3289.55980, saving model to price_prediction.hdf5
#
# Epoch 00035: val_loss did not improve
#
# Epoch 00036: val_loss improved from 3289.55980 to 3283.85840, saving model to price_prediction.hdf5
#
# Epoch 00037: val_loss improved from 3283.85840 to 3283.29465, saving model to price_prediction.hdf5
#
# Epoch 00038: val_loss improved from 3283.29465 to 3280.39425, saving model to price_prediction.hdf5
#
# Epoch 00039: val_loss improved from 3280.39425 to 3279.20422, saving model to price_prediction.hdf5
#
# Epoch 00040: val_loss improved from 3279.20422 to 3276.55069, saving model to price_prediction.hdf5
#
# Epoch 00041: val_loss did not improve
#
# Epoch 00042: val_loss improved from 3276.55069 to 3273.30821, saving model to price_prediction.hdf5
#
# Epoch 00043: val_loss improved from 3273.30821 to 3270.51165, saving model to price_prediction.hdf5
#
# Epoch 00044: val_loss did not improve
#
# Epoch 00045: val_loss improved from 3270.51165 to 3268.63002, saving model to price_prediction.hdf5
#
# Epoch 00046: val_loss did not improve
#
# Epoch 00047: val_loss did not improve
#
# Epoch 00048: val_loss improved from 3268.63002 to 3264.89863, saving model to price_prediction.hdf5
#
# Epoch 00049: val_loss improved from 3264.89863 to 3261.07472, saving model to price_prediction.hdf5
#
# Epoch 00050: val_loss did not improve
#
# Epoch 00051: val_loss did not improve
#
# Epoch 00052: val_loss improved from 3261.07472 to 3261.00201, saving model to price_prediction.hdf5
#
# Epoch 00053: val_loss improved from 3261.00201 to 3258.06308, saving model to price_prediction.hdf5
#
# Epoch 00054: val_loss improved from 3258.06308 to 3253.86555, saving model to price_prediction.hdf5
#
# Epoch 00055: val_loss did not improve
#
# Epoch 00056: val_loss improved from 3253.86555 to 3247.91616, saving model to price_prediction.hdf5
#
# Epoch 00057: val_loss did not improve
#
# Epoch 00058: val_loss improved from 3247.91616 to 3244.80605, saving model to price_prediction.hdf5
#
# Epoch 00059: val_loss did not improve
#
# Epoch 00060: val_loss improved from 3244.80605 to 3243.24315, saving model to price_prediction.hdf5
#
# Epoch 00061: val_loss improved from 3243.24315 to 3243.09128, saving model to price_prediction.hdf5
#
# Epoch 00062: val_loss improved from 3243.09128 to 3238.78081, saving model to price_prediction.hdf5
#
# Epoch 00063: val_loss did not improve
#
# Epoch 00064: val_loss improved from 3238.78081 to 3237.19137, saving model to price_prediction.hdf5
#
# Epoch 00065: val_loss improved from 3237.19137 to 3236.37097, saving model to price_prediction.hdf5
#
# Epoch 00066: val_loss improved from 3236.37097 to 3235.54796, saving model to price_prediction.hdf5
#
# Epoch 00067: val_loss did not improve
#
# Epoch 00068: val_loss improved from 3235.54796 to 3230.74794, saving model to price_prediction.hdf5
#
# Epoch 00069: val_loss improved from 3230.74794 to 3230.34349, saving model to price_prediction.hdf5
#
# Epoch 00070: val_loss did not improve
# 2154/2154 [==============================] - 0s 49us/step
# 'The final model scores 3577.938068981401 for test data.'
# Epoch 00001: val_loss did not improve
#
# Epoch 00002: val_loss did not improve
#
# Epoch 00003: val_loss did not improve
#
# Epoch 00004: val_loss improved from 3230.34349 to 3227.38105, saving model to price_prediction.hdf5
#
# Epoch 00005: val_loss did not improve
#
# Epoch 00006: val_loss improved from 3227.38105 to 3226.20556, saving model to price_prediction.hdf5
#
# Epoch 00007: val_loss improved from 3226.20556 to 3224.74259, saving model to price_prediction.hdf5
#
# Epoch 00008: val_loss did not improve
#
# Epoch 00009: val_loss improved from 3224.74259 to 3223.09266, saving model to price_prediction.hdf5
#
# Epoch 00010: val_loss did not improve
#
# Epoch 00011: val_loss improved from 3223.09266 to 3221.12509, saving model to price_prediction.hdf5
#
# Epoch 00012: val_loss did not improve
#
# Epoch 00013: val_loss did not improve
#
# Epoch 00014: val_loss improved from 3221.12509 to 3216.83817, saving model to price_prediction.hdf5
#
# Epoch 00015: val_loss improved from 3216.83817 to 3216.11622, saving model to price_prediction.hdf5
#
# Epoch 00016: val_loss improved from 3216.11622 to 3213.95391, saving model to price_prediction.hdf5
#
# Epoch 00017: val_loss improved from 3213.95391 to 3213.52270, saving model to price_prediction.hdf5
#
# Epoch 00018: val_loss improved from 3213.52270 to 3211.72894, saving model to price_prediction.hdf5
#
# Epoch 00019: val_loss did not improve
#
# Epoch 00020: val_loss did not improve
#
# Epoch 00021: val_loss did not improve
#
# Epoch 00022: val_loss did not improve
#
# Epoch 00023: val_loss did not improve
#
# Epoch 00024: val_loss improved from 3211.72894 to 3209.80869, saving model to price_prediction.hdf5
#
# Epoch 00025: val_loss improved from 3209.80869 to 3208.18122, saving model to price_prediction.hdf5
#
# Epoch 00026: val_loss did not improve
#
# Epoch 00027: val_loss did not improve
#
# Epoch 00028: val_loss did not improve
#
# Epoch 00029: val_loss did not improve
#
# Epoch 00030: val_loss did not improve
#
# Epoch 00031: val_loss improved from 3208.18122 to 3204.07540, saving model to price_prediction.hdf5
#
# Epoch 00032: val_loss improved from 3204.07540 to 3202.36107, saving model to price_prediction.hdf5
#
# Epoch 00033: val_loss improved from 3202.36107 to 3201.85171, saving model to price_prediction.hdf5
#
# Epoch 00034: val_loss did not improve
#
# Epoch 00035: val_loss improved from 3201.85171 to 3201.18591, saving model to price_prediction.hdf5
#
# Epoch 00036: val_loss did not improve
#
# Epoch 00037: val_loss improved from 3201.18591 to 3201.04869, saving model to price_prediction.hdf5
#
# Epoch 00038: val_loss improved from 3201.04869 to 3200.11637, saving model to price_prediction.hdf5
#
# Epoch 00039: val_loss did not improve
#
# Epoch 00040: val_loss did not improve
#
# Epoch 00041: val_loss improved from 3200.11637 to 3198.93994, saving model to price_prediction.hdf5
#
# Epoch 00042: val_loss improved from 3198.93994 to 3196.52369, saving model to price_prediction.hdf5
#
# Epoch 00043: val_loss did not improve
#
# Epoch 00044: val_loss did not improve
#
# Epoch 00045: val_loss improved from 3196.52369 to 3192.45323, saving model to price_prediction.hdf5
#
# Epoch 00046: val_loss did not improve
#
# Epoch 00047: val_loss did not improve
#
# Epoch 00048: val_loss did not improve
#
# Epoch 00049: val_loss did not improve
#
# Epoch 00050: val_loss improved from 3192.45323 to 3192.11909, saving model to price_prediction.hdf5
#
# Epoch 00051: val_loss did not improve
#
# Epoch 00052: val_loss improved from 3192.11909 to 3190.61411, saving model to price_prediction.hdf5
#
# Epoch 00053: val_loss did not improve
#
# Epoch 00054: val_loss improved from 3190.61411 to 3189.75642, saving model to price_prediction.hdf5
#
# Epoch 00055: val_loss did not improve
#
# Epoch 00056: val_loss improved from 3189.75642 to 3186.95283, saving model to price_prediction.hdf5
#
# Epoch 00057: val_loss did not improve
#
# Epoch 00058: val_loss improved from 3186.95283 to 3186.20391, saving model to price_prediction.hdf5
#
# Epoch 00059: val_loss improved from 3186.20391 to 3183.92911, saving model to price_prediction.hdf5
#
# Epoch 00060: val_loss improved from 3183.92911 to 3183.26442, saving model to price_prediction.hdf5
#
# Epoch 00061: val_loss did not improve
#
# Epoch 00062: val_loss did not improve
#
# Epoch 00063: val_loss improved from 3183.26442 to 3182.04288, saving model to price_prediction.hdf5
#
# Epoch 00064: val_loss improved from 3182.04288 to 3181.77486, saving model to price_prediction.hdf5
#
# Epoch 00065: val_loss did not improve
#
# Epoch 00066: val_loss improved from 3181.77486 to 3178.44863, saving model to price_prediction.hdf5
#
# Epoch 00067: val_loss did not improve
#
# Epoch 00068: val_loss did not improve
#
# Epoch 00069: val_loss did not improve
#
# Epoch 00070: val_loss did not improve
#
# Epoch 00071: val_loss did not improve
#
# Epoch 00072: val_loss improved from 3178.44863 to 3177.08656, saving model to price_prediction.hdf5
#
# Epoch 00073: val_loss did not improve
#
# Epoch 00074: val_loss improved from 3177.08656 to 3176.29812, saving model to price_prediction.hdf5
#
# Epoch 00075: val_loss did not improve
#
# Epoch 00076: val_loss did not improve
#
# Epoch 00077: val_loss did not improve
#
# Epoch 00078: val_loss did not improve
#
# Epoch 00079: val_loss did not improve
#
# Epoch 00080: val_loss did not improve
#
# Epoch 00081: val_loss did not improve
#
# Epoch 00082: val_loss did not improve
#
# Epoch 00083: val_loss improved from 3176.29812 to 3173.59117, saving model to price_prediction.hdf5
#
# Epoch 00084: val_loss did not improve
#
# Epoch 00085: val_loss improved from 3173.59117 to 3171.63550, saving model to price_prediction.hdf5
#
# Epoch 00086: val_loss did not improve
#
# Epoch 00087: val_loss improved from 3171.63550 to 3171.41661, saving model to price_prediction.hdf5
#
# Epoch 00088: val_loss improved from 3171.41661 to 3167.46140, saving model to price_prediction.hdf5
#
# Epoch 00089: val_loss did not improve
#
# Epoch 00090: val_loss did not improve
# 2154/2154 [==============================] - 0s 30us/step
# 'The final model scores 3488.2549426575556 for test data.'
# Epoch 00001: val_loss did not improve
#
# Epoch 00002: val_loss did not improve
#
# Epoch 00003: val_loss did not improve
#
# Epoch 00004: val_loss did not improve
#
# Epoch 00005: val_loss did not improve
#
# Epoch 00006: val_loss did not improve
#
# Epoch 00007: val_loss improved from 3167.46140 to 3167.08203, saving model to price_prediction.hdf5
#
# Epoch 00008: val_loss did not improve
#
# Epoch 00009: val_loss did not improve
#
# Epoch 00010: val_loss did not improve
#
# Epoch 00011: val_loss did not improve
#
# Epoch 00012: val_loss improved from 3167.08203 to 3164.62453, saving model to price_prediction.hdf5
#
# Epoch 00013: val_loss did not improve
#
# Epoch 00014: val_loss did not improve
#
# Epoch 00015: val_loss improved from 3164.62453 to 3162.98438, saving model to price_prediction.hdf5
#
# Epoch 00016: val_loss did not improve
#
# Epoch 00017: val_loss did not improve
#
# Epoch 00018: val_loss did not improve
#
# Epoch 00019: val_loss improved from 3162.98438 to 3160.22388, saving model to price_prediction.hdf5
#
# Epoch 00020: val_loss did not improve
#
# Epoch 00021: val_loss did not improve
#
# Epoch 00022: val_loss did not improve
#
# Epoch 00023: val_loss did not improve
#
# Epoch 00024: val_loss did not improve
#
# Epoch 00025: val_loss improved from 3160.22388 to 3159.92940, saving model to price_prediction.hdf5
#
# Epoch 00026: val_loss did not improve
#
# Epoch 00027: val_loss did not improve
#
# Epoch 00028: val_loss did not improve
#
# Epoch 00029: val_loss did not improve
#
# Epoch 00030: val_loss improved from 3159.92940 to 3159.80469, saving model to price_prediction.hdf5
#
# Epoch 00031: val_loss did not improve
#
# Epoch 00032: val_loss did not improve
#
# Epoch 00033: val_loss did not improve
#
# Epoch 00034: val_loss improved from 3159.80469 to 3158.65562, saving model to price_prediction.hdf5
#
# Epoch 00035: val_loss did not improve
#
# Epoch 00036: val_loss improved from 3158.65562 to 3156.94856, saving model to price_prediction.hdf5
#
# Epoch 00037: val_loss did not improve
#
# Epoch 00038: val_loss did not improve
#
# Epoch 00039: val_loss did not improve
#
# Epoch 00040: val_loss did not improve
#
# Epoch 00041: val_loss did not improve
#
# Epoch 00042: val_loss did not improve
#
# Epoch 00043: val_loss improved from 3156.94856 to 3156.51311, saving model to price_prediction.hdf5
#
# Epoch 00044: val_loss did not improve
#
# Epoch 00045: val_loss improved from 3156.51311 to 3156.11172, saving model to price_prediction.hdf5
#
# Epoch 00046: val_loss improved from 3156.11172 to 3153.76837, saving model to price_prediction.hdf5
#
# Epoch 00047: val_loss did not improve
#
# Epoch 00048: val_loss improved from 3153.76837 to 3153.29295, saving model to price_prediction.hdf5
#
# Epoch 00049: val_loss did not improve
#
# Epoch 00050: val_loss did not improve
#
# Epoch 00051: val_loss improved from 3153.29295 to 3153.28220, saving model to price_prediction.hdf5
#
# Epoch 00052: val_loss did not improve
#
# Epoch 00053: val_loss improved from 3153.28220 to 3151.58928, saving model to price_prediction.hdf5
#
# Epoch 00054: val_loss did not improve
#
# Epoch 00055: val_loss did not improve
#
# Epoch 00056: val_loss did not improve
#
# Epoch 00057: val_loss did not improve
#
# Epoch 00058: val_loss improved from 3151.58928 to 3149.81466, saving model to price_prediction.hdf5
#
# Epoch 00059: val_loss did not improve
#
# Epoch 00060: val_loss improved from 3149.81466 to 3149.81335, saving model to price_prediction.hdf5
#
# Epoch 00061: val_loss did not improve
#
# Epoch 00062: val_loss did not improve
#
# Epoch 00063: val_loss did not improve
#
# Epoch 00064: val_loss did not improve
#
# Epoch 00065: val_loss did not improve
#
# Epoch 00066: val_loss improved from 3149.81335 to 3148.55828, saving model to price_prediction.hdf5
#
# Epoch 00067: val_loss did not improve
#
# Epoch 00068: val_loss did not improve
#
# Epoch 00069: val_loss did not improve
#
# Epoch 00070: val_loss did not improve
#
# Epoch 00071: val_loss improved from 3148.55828 to 3146.84875, saving model to price_prediction.hdf5
#
# Epoch 00072: val_loss did not improve
#
# Epoch 00073: val_loss did not improve
#
# Epoch 00074: val_loss did not improve
#
# Epoch 00075: val_loss did not improve
#
# Epoch 00076: val_loss did not improve
#
# Epoch 00077: val_loss did not improve
#
# Epoch 00078: val_loss did not improve
#
# Epoch 00079: val_loss improved from 3146.84875 to 3145.77322, saving model to price_prediction.hdf5
#
# Epoch 00080: val_loss did not improve
#
# Epoch 00081: val_loss did not improve
#
# Epoch 00082: val_loss did not improve
#
# Epoch 00083: val_loss did not improve
#
# Epoch 00084: val_loss improved from 3145.77322 to 3142.11724, saving model to price_prediction.hdf5
#
# Epoch 00085: val_loss did not improve
#
# Epoch 00086: val_loss did not improve
#
# Epoch 00087: val_loss did not improve
#
# Epoch 00088: val_loss did not improve
#
# Epoch 00089: val_loss did not improve
#
# Epoch 00090: val_loss did not improve
#
# Epoch 00091: val_loss did not improve
#
# Epoch 00092: val_loss did not improve
#
# Epoch 00093: val_loss did not improve
#
# Epoch 00094: val_loss did not improve
#
# Epoch 00095: val_loss did not improve
#
# Epoch 00096: val_loss did not improve
#
# Epoch 00097: val_loss did not improve
#
# Epoch 00098: val_loss did not improve
#
# Epoch 00099: val_loss did not improve
#
# Epoch 00100: val_loss did not improve
#
# Epoch 00101: val_loss did not improve
#
# Epoch 00102: val_loss improved from 3142.11724 to 3140.42111, saving model to price_prediction.hdf5
#
# Epoch 00103: val_loss improved from 3140.42111 to 3139.52274, saving model to price_prediction.hdf5
#
# Epoch 00104: val_loss did not improve
#
# Epoch 00105: val_loss did not improve
#
# Epoch 00106: val_loss did not improve
#
# Epoch 00107: val_loss did not improve
#
# Epoch 00108: val_loss did not improve
#
# Epoch 00109: val_loss improved from 3139.52274 to 3137.77103, saving model to price_prediction.hdf5
#
# Epoch 00110: val_loss did not improve
# 2154/2154 [==============================] - 0s 32us/step
# 'The final model scores 3457.971031366063 for test data.'
# Epoch 00001: val_loss did not improve
#
# Epoch 00002: val_loss did not improve
#
# Epoch 00003: val_loss did not improve
#
# Epoch 00004: val_loss did not improve
#
# Epoch 00005: val_loss did not improve
#
# Epoch 00006: val_loss did not improve
#
# Epoch 00007: val_loss did not improve
#
# Epoch 00008: val_loss did not improve
#
# Epoch 00009: val_loss did not improve
#
# Epoch 00010: val_loss did not improve
#
# Epoch 00011: val_loss did not improve
#
# Epoch 00012: val_loss did not improve
#
# Epoch 00013: val_loss improved from 3137.77103 to 3134.88087, saving model to price_prediction.hdf5
#
# Epoch 00014: val_loss did not improve
#
# Epoch 00015: val_loss did not improve
#
# Epoch 00016: val_loss did not improve
#
# Epoch 00017: val_loss did not improve
#
# Epoch 00018: val_loss did not improve
#
# Epoch 00019: val_loss did not improve
#
# Epoch 00020: val_loss did not improve
#
# Epoch 00021: val_loss did not improve
#
# Epoch 00022: val_loss did not improve
#
# Epoch 00023: val_loss did not improve
#
# Epoch 00024: val_loss did not improve
#
# Epoch 00025: val_loss did not improve
#
# Epoch 00026: val_loss did not improve
#
# Epoch 00027: val_loss did not improve
#
# Epoch 00028: val_loss did not improve
#
# Epoch 00029: val_loss did not improve
#
# Epoch 00030: val_loss improved from 3134.88087 to 3134.00108, saving model to price_prediction.hdf5
#
# Epoch 00031: val_loss did not improve
#
# Epoch 00032: val_loss did not improve
#
# Epoch 00033: val_loss improved from 3134.00108 to 3133.13777, saving model to price_prediction.hdf5
#
# Epoch 00034: val_loss did not improve
#
# Epoch 00035: val_loss did not improve
#
# Epoch 00036: val_loss did not improve
#
# Epoch 00037: val_loss did not improve
#
# Epoch 00038: val_loss did not improve
#
# Epoch 00039: val_loss did not improve
#
# Epoch 00040: val_loss did not improve
#
# Epoch 00041: val_loss did not improve
#
# Epoch 00042: val_loss did not improve
#
# Epoch 00043: val_loss improved from 3133.13777 to 3132.61553, saving model to price_prediction.hdf5
#
# Epoch 00044: val_loss improved from 3132.61553 to 3132.09776, saving model to price_prediction.hdf5
#
# Epoch 00045: val_loss did not improve
#
# Epoch 00046: val_loss did not improve
#
# Epoch 00047: val_loss did not improve
#
# Epoch 00048: val_loss improved from 3132.09776 to 3129.73533, saving model to price_prediction.hdf5
#
# Epoch 00049: val_loss did not improve
#
# Epoch 00050: val_loss improved from 3129.73533 to 3128.03597, saving model to price_prediction.hdf5
#
# Epoch 00051: val_loss did not improve
#
# Epoch 00052: val_loss did not improve
#
# Epoch 00053: val_loss did not improve
#
# Epoch 00054: val_loss did not improve
#
# Epoch 00055: val_loss did not improve
#
# Epoch 00056: val_loss did not improve
#
# Epoch 00057: val_loss did not improve
#
# Epoch 00058: val_loss did not improve
#
# Epoch 00059: val_loss did not improve
#
# Epoch 00060: val_loss did not improve
#
# Epoch 00061: val_loss did not improve
#
# Epoch 00062: val_loss did not improve
#
# Epoch 00063: val_loss did not improve
#
# Epoch 00064: val_loss did not improve
#
# Epoch 00065: val_loss did not improve
#
# Epoch 00066: val_loss did not improve
#
# Epoch 00067: val_loss did not improve
#
# Epoch 00068: val_loss did not improve
#
# Epoch 00069: val_loss did not improve
#
# Epoch 00070: val_loss did not improve
#
# Epoch 00071: val_loss did not improve
#
# Epoch 00072: val_loss did not improve
#
# Epoch 00073: val_loss did not improve
#
# Epoch 00074: val_loss did not improve
#
# Epoch 00075: val_loss did not improve
#
# Epoch 00076: val_loss did not improve
#
# Epoch 00077: val_loss did not improve
#
# Epoch 00078: val_loss did not improve
#
# Epoch 00079: val_loss did not improve
#
# Epoch 00080: val_loss improved from 3128.03597 to 3127.50395, saving model to price_prediction.hdf5
#
# Epoch 00081: val_loss did not improve
#
# Epoch 00082: val_loss did not improve
#
# Epoch 00083: val_loss did not improve
#
# Epoch 00084: val_loss did not improve
#
# Epoch 00085: val_loss did not improve
#
# Epoch 00086: val_loss improved from 3127.50395 to 3126.65366, saving model to price_prediction.hdf5
#
# Epoch 00087: val_loss did not improve
#
# Epoch 00088: val_loss improved from 3126.65366 to 3126.49172, saving model to price_prediction.hdf5
#
# Epoch 00089: val_loss did not improve
#
# Epoch 00090: val_loss did not improve
#
# Epoch 00091: val_loss did not improve
#
# Epoch 00092: val_loss improved from 3126.49172 to 3126.36310, saving model to price_prediction.hdf5
#
# Epoch 00093: val_loss improved from 3126.36310 to 3124.76239, saving model to price_prediction.hdf5
#
# Epoch 00094: val_loss did not improve
#
# Epoch 00095: val_loss did not improve
#
# Epoch 00096: val_loss did not improve
#
# Epoch 00097: val_loss did not improve
#
# Epoch 00098: val_loss did not improve
#
# Epoch 00099: val_loss did not improve
#
# Epoch 00100: val_loss did not improve
#
# Epoch 00101: val_loss improved from 3124.76239 to 3123.86989, saving model to price_prediction.hdf5
#
# Epoch 00102: val_loss did not improve
#
# Epoch 00103: val_loss did not improve
#
# Epoch 00104: val_loss improved from 3123.86989 to 3122.46124, saving model to price_prediction.hdf5
#
# Epoch 00105: val_loss did not improve
#
# Epoch 00106: val_loss did not improve
#
# Epoch 00107: val_loss did not improve
#
# Epoch 00108: val_loss improved from 3122.46124 to 3122.01894, saving model to price_prediction.hdf5
#
# Epoch 00109: val_loss did not improve
#
# Epoch 00110: val_loss did not improve
#
# Epoch 00111: val_loss did not improve
#
# Epoch 00112: val_loss did not improve
#
# Epoch 00113: val_loss improved from 3122.01894 to 3121.65311, saving model to price_prediction.hdf5
#
# Epoch 00114: val_loss did not improve
#
# Epoch 00115: val_loss did not improve
#
# Epoch 00116: val_loss did not improve
#
# Epoch 00117: val_loss improved from 3121.65311 to 3119.43508, saving model to price_prediction.hdf5
#
# Epoch 00118: val_loss did not improve
#
# Epoch 00119: val_loss did not improve
#
# Epoch 00120: val_loss did not improve
#
# Epoch 00121: val_loss did not improve
#
# Epoch 00122: val_loss did not improve
#
# Epoch 00123: val_loss did not improve
#
# Epoch 00124: val_loss did not improve
#
# Epoch 00125: val_loss did not improve
#
# Epoch 00126: val_loss did not improve
#
# Epoch 00127: val_loss did not improve
#
# Epoch 00128: val_loss did not improve
#
# Epoch 00129: val_loss did not improve
#
# Epoch 00130: val_loss did not improve
# 2154/2154 [==============================] - 0s 30us/step
# 'The final model scores 3460.1051563769443 for test data.'
# Epoch 00001: val_loss did not improve
#
# Epoch 00002: val_loss did not improve
#
# Epoch 00003: val_loss did not improve
#
# Epoch 00004: val_loss did not improve
#
# Epoch 00005: val_loss did not improve
#
# Epoch 00006: val_loss did not improve
#
# Epoch 00007: val_loss did not improve
#
# Epoch 00008: val_loss did not improve
#
# Epoch 00009: val_loss did not improve
#
# Epoch 00010: val_loss did not improve
#
# Epoch 00011: val_loss did not improve
#
# Epoch 00012: val_loss did not improve
#
# Epoch 00013: val_loss did not improve
#
# Epoch 00014: val_loss did not improve
#
# Epoch 00015: val_loss improved from 3119.43508 to 3117.87186, saving model to price_prediction.hdf5
#
# Epoch 00016: val_loss did not improve
#
# Epoch 00017: val_loss did not improve
#
# Epoch 00018: val_loss did not improve
#
# Epoch 00019: val_loss did not improve
#
# Epoch 00020: val_loss did not improve
#
# Epoch 00021: val_loss did not improve
#
# Epoch 00022: val_loss did not improve
#
# Epoch 00023: val_loss did not improve
#
# Epoch 00024: val_loss did not improve
#
# Epoch 00025: val_loss did not improve
#
# Epoch 00026: val_loss did not improve
#
# Epoch 00027: val_loss did not improve
#
# Epoch 00028: val_loss did not improve
#
# Epoch 00029: val_loss did not improve
#
# Epoch 00030: val_loss did not improve
#
# Epoch 00031: val_loss did not improve
#
# Epoch 00032: val_loss did not improve
#
# Epoch 00033: val_loss did not improve
#
# Epoch 00034: val_loss did not improve
#
# Epoch 00035: val_loss did not improve
#
# Epoch 00036: val_loss did not improve
#
# Epoch 00037: val_loss did not improve
#
# Epoch 00038: val_loss improved from 3117.87186 to 3117.09014, saving model to price_prediction.hdf5
#
# Epoch 00039: val_loss did not improve
#
# Epoch 00040: val_loss did not improve
#
# Epoch 00041: val_loss did not improve
#
# Epoch 00042: val_loss did not improve
#
# Epoch 00043: val_loss did not improve
#
# Epoch 00044: val_loss did not improve
#
# Epoch 00045: val_loss did not improve
#
# Epoch 00046: val_loss did not improve
#
# Epoch 00047: val_loss did not improve
#
# Epoch 00048: val_loss did not improve
#
# Epoch 00049: val_loss did not improve
#
# Epoch 00050: val_loss did not improve
#
# Epoch 00051: val_loss did not improve
#
# Epoch 00052: val_loss improved from 3117.09014 to 3116.41607, saving model to price_prediction.hdf5
#
# Epoch 00053: val_loss did not improve
#
# Epoch 00054: val_loss improved from 3116.41607 to 3114.71754, saving model to price_prediction.hdf5
#
# Epoch 00055: val_loss did not improve
#
# Epoch 00056: val_loss did not improve
#
# Epoch 00057: val_loss did not improve
#
# Epoch 00058: val_loss did not improve
#
# Epoch 00059: val_loss improved from 3114.71754 to 3113.46158, saving model to price_prediction.hdf5
#
# Epoch 00060: val_loss did not improve
#
# Epoch 00061: val_loss did not improve
#
# Epoch 00062: val_loss did not improve
#
# Epoch 00063: val_loss did not improve
#
# Epoch 00064: val_loss did not improve
#
# Epoch 00065: val_loss did not improve
#
# Epoch 00066: val_loss improved from 3113.46158 to 3112.82543, saving model to price_prediction.hdf5
#
# Epoch 00067: val_loss did not improve
#
# Epoch 00068: val_loss did not improve
#
# Epoch 00069: val_loss did not improve
#
# Epoch 00070: val_loss did not improve
#
# Epoch 00071: val_loss did not improve
#
# Epoch 00072: val_loss did not improve
#
# Epoch 00073: val_loss did not improve
#
# Epoch 00074: val_loss did not improve
#
# Epoch 00075: val_loss did not improve
#
# Epoch 00076: val_loss did not improve
#
# Epoch 00077: val_loss did not improve
#
# Epoch 00078: val_loss did not improve
#
# Epoch 00079: val_loss did not improve
#
# Epoch 00080: val_loss did not improve
#
# Epoch 00081: val_loss did not improve
#
# Epoch 00082: val_loss did not improve
#
# Epoch 00083: val_loss did not improve
#
# Epoch 00084: val_loss improved from 3112.82543 to 3112.76561, saving model to price_prediction.hdf5
#
# Epoch 00085: val_loss did not improve
#
# Epoch 00086: val_loss did not improve
#
# Epoch 00087: val_loss improved from 3112.76561 to 3111.43719, saving model to price_prediction.hdf5
#
# Epoch 00088: val_loss did not improve
#
# Epoch 00089: val_loss did not improve
#
# Epoch 00090: val_loss did not improve
#
# Epoch 00091: val_loss did not improve
#
# Epoch 00092: val_loss did not improve
#
# Epoch 00093: val_loss did not improve
#
# Epoch 00094: val_loss improved from 3111.43719 to 3110.13833, saving model to price_prediction.hdf5
#
# Epoch 00095: val_loss did not improve
#
# Epoch 00096: val_loss did not improve
#
# Epoch 00097: val_loss did not improve
#
# Epoch 00098: val_loss did not improve
#
# Epoch 00099: val_loss did not improve
#
# Epoch 00100: val_loss did not improve
#
# Epoch 00101: val_loss improved from 3110.13833 to 3109.87252, saving model to price_prediction.hdf5
#
# Epoch 00102: val_loss did not improve
#
# Epoch 00103: val_loss did not improve
#
# Epoch 00104: val_loss did not improve
#
# Epoch 00105: val_loss did not improve
#
# Epoch 00106: val_loss did not improve
#
# Epoch 00107: val_loss did not improve
#
# Epoch 00108: val_loss did not improve
#
# Epoch 00109: val_loss improved from 3109.87252 to 3109.08956, saving model to price_prediction.hdf5
#
# Epoch 00110: val_loss did not improve
#
# Epoch 00111: val_loss did not improve
#
# Epoch 00112: val_loss improved from 3109.08956 to 3108.13647, saving model to price_prediction.hdf5
#
# Epoch 00113: val_loss did not improve
#
# Epoch 00114: val_loss did not improve
#
# Epoch 00115: val_loss did not improve
#
# Epoch 00116: val_loss did not improve
#
# Epoch 00117: val_loss did not improve
#
# Epoch 00118: val_loss did not improve
#
# Epoch 00119: val_loss did not improve
#
# Epoch 00120: val_loss did not improve
#
# Epoch 00121: val_loss did not improve
#
# Epoch 00122: val_loss did not improve
#
# Epoch 00123: val_loss did not improve
#
# Epoch 00124: val_loss did not improve
#
# Epoch 00125: val_loss did not improve
#
# Epoch 00126: val_loss did not improve
#
# Epoch 00127: val_loss improved from 3108.13647 to 3107.84991, saving model to price_prediction.hdf5
#
# Epoch 00128: val_loss did not improve
#
# Epoch 00129: val_loss did not improve
#
# Epoch 00130: val_loss did not improve
#
# Epoch 00131: val_loss did not improve
#
# Epoch 00132: val_loss did not improve
#
# Epoch 00133: val_loss did not improve
#
# Epoch 00134: val_loss did not improve
#
# Epoch 00135: val_loss did not improve
#
# Epoch 00136: val_loss improved from 3107.84991 to 3105.99686, saving model to price_prediction.hdf5
#
# Epoch 00137: val_loss did not improve
#
# Epoch 00138: val_loss did not improve
#
# Epoch 00139: val_loss did not improve
#
# Epoch 00140: val_loss did not improve
#
# Epoch 00141: val_loss did not improve
#
# Epoch 00142: val_loss did not improve
#
# Epoch 00143: val_loss did not improve
#
# Epoch 00144: val_loss did not improve
#
# Epoch 00145: val_loss did not improve
#
# Epoch 00146: val_loss did not improve
#
# Epoch 00147: val_loss did not improve
#
# Epoch 00148: val_loss did not improve
#
# Epoch 00149: val_loss did not improve
#
# Epoch 00150: val_loss did not improve
# 2154/2154 [==============================] - 0s 40us/step
# 'The final model scores 3437.476927010794 for test data.'
# "model = Sequential([\n    Dense(85, activation='relu', input_shape=(1079,)),\n    Dense(85, activation='relu'),\n    Dense(1, activation='sigmoid'),\n])\n\nmodel.compile(optimizer='sgd',\n              loss='binary_crossentropy',\n              metrics=['accuracy'])\n\n\nmodel.fit(X_train, y_train,\n          batch_size=32, epochs=10,\n          validation_data=(X_val, y_val))"

# %%
import matplotlib.pyplot as plt
plt.title("NN test error")
plt.xlabel("Number of epochs")
plt.ylabel("Error")
plt.plot(epoch, test_errs, 'r')
plt.show()

# %%
num_samples=50
idx=random.sample(range(len(y_test)),num_samples) 
plt.plot(range(num_samples),y_test[idx],'ro-')
plt.plot(range(num_samples),price_prediction[idx],'bx-')
plt.ylabel("price")
plt.legend(["actual price",'predicted price','mean price'])

# %%
dictData = {}
dictData['X_train'] = X_train
dictData['X_test'] = X_test
dictData['Y_train'] = y_train
dictData['y_test'] = y_test

# %%
display(dictData['Y_train'])
# Out:
# array([ 5100,  7995,  5400, ..., 15999, 13499, 21865])

# %%
display(dictData['y_test'])
# Out:
# array([ 7750, 21991, 12950, ...,  4600, 34995, 13950])
